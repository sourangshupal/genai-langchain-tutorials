# %% [markdown]
# # 📚 Notebook 01: Introduction and Fundamentals
#
# **LangChain 1.0.5+ | Mixed Level Class**
#
# ---
#
# ## 🎯 Learning Objectives
#
# By the end of this notebook, you will understand:
# 1. What LangChain is and why it's useful
# 2. LangChain's modular architecture
# 3. Core concepts: Documents, Chains, and LCEL
# 4. How to set up your development environment
# 5. The difference between LangChain and traditional ML pipelines
#
# ---
#
# ## 📖 Table of Contents
#
# 1. [What is LangChain?](#what-is-langchain)
# 2. [LangChain Architecture](#architecture)
# 3. [Environment Setup](#setup)
# 4. [Core Concepts](#core-concepts)
# 5. [Quick Start Example](#quick-start)
# 6. [LangChain vs Traditional Pipelines](#comparison)
# 7. [Summary & Next Steps](#summary)
#
# ---

# %% [markdown]
# <a id="what-is-langchain"></a>
# ## 1. What is LangChain? 🤔
#
# ### 🔰 BEGINNER SECTION
#
# **LangChain** is an open-source framework that makes it easy to build applications powered by Large Language Models (LLMs) like GPT-4, Claude, or Llama.
#
# ### Why LangChain?
#
# Imagine you want to build a chatbot that can:
# - Answer questions about your company's PDF documents
# - Search through your database
# - Remember previous conversations
# - Call external APIs
#
# Without LangChain, you'd need to:
# 1. ✍️ Write code to load and parse PDFs
# 2. ✍️ Convert text to embeddings
# 3. ✍️ Store embeddings in a vector database
# 4. ✍️ Implement semantic search
# 5. ✍️ Format prompts for the LLM
# 6. ✍️ Handle LLM API calls
# 7. ✍️ Manage conversation memory
#
# **With LangChain:**
# - ✅ All these components are pre-built and ready to use
# - ✅ You just connect them like LEGO blocks
# - ✅ Focus on your application logic, not infrastructure
#
# ### 🎓 INTERMEDIATE NOTE
#
# LangChain provides:
# - **Abstractions**: Unified interfaces for different LLMs, vector stores, and tools
# - **Chains**: Composable workflows using LCEL (LangChain Expression Language)
# - **Agents**: Autonomous systems that can use tools and make decisions
# - **Memory**: Conversation history and context management
# - **Callbacks**: Monitoring, logging, and debugging hooks

# %% [markdown]
# <a id="architecture"></a>
# ## 2. LangChain Architecture 🏗️
#
# ### 🔰 BEGINNER: Visual Architecture
#
# ```
# ┌─────────────────────────────────────────────────────────┐
# │                    YOUR APPLICATION                     │
# └─────────────────────────────────────────────────────────┘
#                            ↓
# ┌─────────────────────────────────────────────────────────┐
# │                  LANGCHAIN FRAMEWORK                    │
# │  ┌──────────┐  ┌──────────┐  ┌──────────┐  ┌─────────┐  │
# │  │ Document │  │   Text   │  │ Embeddings│  │ Vector  │ │
# │  │ Loaders  │→ │ Splitters│→ │  Models   │→ │ Stores  │ │
# │  └──────────┘  └──────────┘  └──────────┘  └─────────┘│
# │                                                         │
# │  ┌──────────┐  ┌──────────┐  ┌──────────┐               │
# │  │Retrievers│  │ Prompts  │  │   LLMs   │               │
# │  └──────────┘  └──────────┘  └──────────┘               │
# │                                                         │
# │  ┌──────────────────────────────────────────────────┐   │
# │  │         LCEL (LangChain Expression Language)     │   │
# │  │         Connects everything with | operator      │   │
# │  └──────────────────────────────────────────────────┘   │
# └─────────────────────────────────────────────────────────┘
#                            ↓
# ┌─────────────────────────────────────────────────────────┐
# │             EXTERNAL SERVICES & DATA                    │
# │  • OpenAI/Anthropic APIs  • Vector Databases            │
# │  • PDF Files              • Websites                    │
# │  • Databases              • APIs                        │
# └─────────────────────────────────────────────────────────┘
# ```
#
# ### 🎓 INTERMEDIATE: Package Structure (LangChain 1.0+)
#
# LangChain is organized into several packages:
#
# | Package | Purpose | Example Imports |
# |---------|---------|------------------|
# | **langchain-core** | Core abstractions, base classes | `from langchain_core.documents import Document` |
# | **langchain-community** | Community integrations (loaders, vector stores) | `from langchain_community.document_loaders import PyPDFLoader` |
# | **langchain-openai** | OpenAI-specific integrations | `from langchain_openai import ChatOpenAI, OpenAIEmbeddings` |
# | **langchain-text-splitters** | Text splitting utilities | `from langchain_text_splitters import RecursiveCharacterTextSplitter` |
#
# **Why this matters:** In LangChain 1.0+, you import from specific packages instead of `langchain` directly. This reduces dependencies and improves modularity.

# %% [markdown]
# <a id="setup"></a>
# ## 3. Environment Setup 🛠️
#
# ### 🔰 BEGINNER: Step-by-Step Setup
#
# Let's verify your environment is ready!

# %%
# Step 1: Check Python version (should be 3.9+)
import sys
print(f"Python version: {sys.version}")

# Check if Python is 3.9 or higher
if sys.version_info >= (3, 9):
    print("✅ Python version is compatible")
else:
    print("❌ Please upgrade to Python 3.9 or higher")
# Out:
# Python version: 3.12.9 (main, Mar 17 2025, 21:36:21) [Clang 20.1.0 ]
# ✅ Python version is compatible

# %%
# Step 2: Import LangChain and check version
import langchain
from langchain_core import __version__ as core_version

print(f"LangChain version: {langchain.__version__}")
print(f"LangChain Core version: {core_version}")

# We're using LangChain 1.0.5+ for this course
if langchain.__version__ >= "1.0":
    print("✅ LangChain 1.0+ detected")
else:
    print("❌ Please upgrade: pip install --upgrade langchain")
# Out:
# LangChain version: 1.2.12
# LangChain Core version: 1.2.19
# ✅ LangChain 1.0+ detected

# %%
# Step 3: Load environment variables (API keys)
from dotenv import load_dotenv
import os

# Load .env file
load_dotenv()

# Check if OpenAI API key is set
# NOTE: We don't print the actual key for security!
if os.getenv("OPENAI_API_KEY"):
    print("✅ OPENAI_API_KEY found")
else:
    print("❌ OPENAI_API_KEY not found")
    print("   Create a .env file with: OPENAI_API_KEY=your-key-here")

# Check for Google API key (optional, for Google Gemini)
if os.getenv("GOOGLE_API_KEY"):
    print("✅ GOOGLE_API_KEY found")
else:
    print("⚠️  GOOGLE_API_KEY not found (optional for this notebook)")
# Out:
# ✅ OPENAI_API_KEY found
# ✅ GOOGLE_API_KEY found

# %% [markdown]
# ### 📝 Setting Up Your .env File
#
# If you don't have a `.env` file, create one in the project root:
#
# ```bash
# # .env file
# OPENAI_API_KEY=sk-proj-your-key-here
# GOOGLE_API_KEY=your-google-key-here
# ```
#
# **⚠️ SECURITY WARNING:**
# - Never commit `.env` files to Git
# - Add `.env` to your `.gitignore` file
# - Never hardcode API keys in your code

# %% [markdown]
# <a id="core-concepts"></a>
# ## 4. Core Concepts 📚
#
# ### 4.1 Documents 📄
#
# ### 🔰 BEGINNER
#
# A **Document** is LangChain's way of representing a piece of text with metadata.
#
# Think of it like a note card:
# - **Front (page_content):** The actual text
# - **Back (metadata):** Information about the text (source, page number, date, etc.)

# %%
# Creating a Document manually
from langchain_core.documents import Document

# Create a simple document
doc = Document(
    page_content="LangChain makes building LLM applications easy!",
    metadata={
        "source": "introduction.txt",
        "author": "LangChain Team",
        "date": "2025-01-15"
    }
)

# Access the content
print("Content:")
print(doc.page_content)
print("\nMetadata:")
print(doc.metadata)
print(f"\nSource: {doc.metadata['source']}")
# Out:
# Content:
# LangChain makes building LLM applications easy!
#
# Metadata:
# {'source': 'introduction.txt', 'author': 'LangChain Team', 'date': '2025-01-15'}
#
# Source: introduction.txt

# %% [markdown]
# ### 🎓 INTERMEDIATE: Why Metadata Matters
#
# Metadata is crucial for:
# 1. **Citation**: Showing users where information came from
# 2. **Filtering**: Only search documents from specific sources
# 3. **Debugging**: Tracking which documents are being retrieved
# 4. **Analytics**: Understanding which sources are most useful

# %%
# Creating multiple documents (like a mini knowledge base)
documents = [
    Document(
        page_content="Python is a high-level programming language.",
        metadata={"category": "programming", "difficulty": "beginner"}
    ),
    Document(
        page_content="Machine learning is a subset of artificial intelligence.",
        metadata={"category": "AI", "difficulty": "intermediate"}
    ),
    Document(
        page_content="RAG combines retrieval and generation for better LLM outputs.",
        metadata={"category": "AI", "difficulty": "advanced"}
    )
]

# Print all documents
for i, doc in enumerate(documents, 1):
    print(f"\n📄 Document {i}:")
    print(f"   Content: {doc.page_content}")
    print(f"   Category: {doc.metadata['category']}")
    print(f"   Difficulty: {doc.metadata['difficulty']}")
# Out:
# 📄 Document 1:
#    Content: Python is a high-level programming language.
#    Category: programming
#    Difficulty: beginner
#
# 📄 Document 2:
#    Content: Machine learning is a subset of artificial intelligence.
#    Category: AI
#    Difficulty: intermediate
#
# 📄 Document 3:
#    Content: RAG combines retrieval and generation for better LLM outputs.
#    Category: AI
#    Difficulty: advanced

# %% [markdown]
# ### 4.2 LCEL (LangChain Expression Language) 🔗
#
# ### 🔰 BEGINNER
#
# **LCEL** is a way to connect different components using the pipe operator `|`.
#
# Think of it like a factory assembly line:
# ```
# Input → Component 1 → Component 2 → Component 3 → Output
# ```
#
# ### Before LCEL (Old Way - Messy!):
# ```python
# output = component3(component2(component1(input)))
# ```
#
# ### With LCEL (New Way - Clean!):
# ```python
# chain = component1 | component2 | component3
# output = chain.invoke(input)
# ```

# %% [markdown]
# ### 🎓 INTERMEDIATE: LCEL Deep Dive
#
# LCEL provides:
# - **Streaming**: Stream outputs as they're generated
# - **Batch Processing**: Process multiple inputs efficiently
# - **Async Support**: Non-blocking operations
# - **Debugging**: Better error messages and logging
# - **Type Safety**: Better IDE autocomplete
#
# **Key Methods:**
# - `.invoke(input)`: Process single input
# - `.batch([input1, input2])`: Process multiple inputs
# - `.stream(input)`: Stream output tokens
# - `.ainvoke(input)`: Async version of invoke

# %%
# Simple LCEL Example: String Transformation Chain
from langchain_core.runnables import RunnableLambda

# Create simple transformation functions
def uppercase(text: str) -> str:
    """Convert text to uppercase"""
    print(f"  Step 1: uppercase → {text.upper()}")
    return text.upper()

def add_prefix(text: str) -> str:
    """Add a prefix to text"""
    result = f"RESULT: {text}"
    print(f"  Step 2: add_prefix → {result}")
    return result

def add_emoji(text: str) -> str:
    """Add emoji to text"""
    result = f"✅ {text}"
    print(f"  Step 3: add_emoji → {result}")
    return result

# Create runnables (components that can be chained)
uppercase_runnable = RunnableLambda(uppercase)
prefix_runnable = RunnableLambda(add_prefix)
emoji_runnable = RunnableLambda(add_emoji)

# Build the chain using LCEL
chain = uppercase_runnable | prefix_runnable | emoji_runnable

# Execute the chain
print("Input: 'hello langchain'")
print("\nProcessing:")
result = chain.invoke("hello langchain")
print(f"\nFinal Output: {result}")
# Out:
# Input: 'hello langchain'
#
# Processing:
#   Step 1: uppercase → HELLO LANGCHAIN
#   Step 2: add_prefix → RESULT: HELLO LANGCHAIN
#   Step 3: add_emoji → ✅ RESULT: HELLO LANGCHAIN
#
# Final Output: ✅ RESULT: HELLO LANGCHAIN

# %% [markdown]
# ### 4.3 Chains 🔗
#
# ### 🔰 BEGINNER
#
# A **Chain** is a sequence of operations. Common chain types:
#
# 1. **Simple Chain**: Input → Process → Output
# 2. **RAG Chain**: Query → Retrieve → Generate → Answer
# 3. **Multi-step Chain**: Input → Step 1 → Step 2 → Step 3 → Output
#
# We'll build complex chains in later notebooks!

# %% [markdown]
# <a id="quick-start"></a>
# ## 5. Quick Start Example 🚀
#
# ### 🔰 BEGINNER: Your First LLM Call
#
# Let's make our first call to an LLM using LangChain!

# %%
# Import ChatOpenAI (the LLM interface)
from langchain_openai import ChatOpenAI

# Initialize the LLM
# model: Which GPT model to use
# temperature: 0 = deterministic, 1 = creative
llm = ChatOpenAI(
    model="gpt-5-nano",  # Cheaper, faster model for learning
    temperature=0  # Deterministic outputs for learning
)

# Make a simple call
response = llm.invoke("What is LangChain in two sentences?")

# Print the response
print("Question: What is LangChain in one sentence?")
print(f"\nAnswer: {response.content}")
# Out:
# Question: What is LangChain in one sentence?
#
# Answer: LangChain is an open-source framework for building applications powered by large language models. It provides modular components such as prompts, chains, agents, memory, and tool integrations to orchestrate reasoning, retrieval, and actions with LLMs.

# %% [markdown]
# ### FOR GEMINI

# %%
#!uv pip install -U langchain-google-genai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(
model="gemini-2.5-flash",  # Example Gemini model
temperature=0  # Deterministic outputs for learning
)

# Make a simple call
response = llm.invoke("What is LangChain in one sentence?")

# Print the response
print("Question: What is LangChain in one sentence?")
print(f"\nAnswer: {response.content}")
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Question: What is LangChain in one sentence?
#
# Answer: LangChain is a development framework designed to build applications with large language models by orchestrating their interactions with external data and tools.

# %%
# !uv pip install langchain-groq

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
model="openai/gpt-oss-120b",  # Example Gemini model
temperature=0  # Deterministic outputs for learning
)

# Make a simple call
response = llm.invoke("What is LangChain in one sentence?")

# Print the response
print("Question: What is LangChain in one sentence?")
print(f"\nAnswer: {response.content}")
# Out:
# Question: What is LangChain in one sentence?
#
# Answer: LangChain is a framework that enables developers to build applications powered by large language models by chaining together prompts, models, and external tools in a modular, programmable workflow.

# %% [markdown]
# ### 🎓 INTERMEDIATE: Understanding the Response Object

# %%
# The response is an AIMessage object with metadata
print("Response Type:", type(response))
print("\nContent:", response.content)
print("\nResponse Metadata:")
print(response.response_metadata)

# Access specific metadata
if 'token_usage' in response.response_metadata:
    usage = response.response_metadata['token_usage']
    print(f"\nTokens Used:")
    print(f"  Prompt: {usage.get('prompt_tokens', 'N/A')}")
    print(f"  Completion: {usage.get('completion_tokens', 'N/A')}")
    print(f"  Total: {usage.get('total_tokens', 'N/A')}")
# Out:
# Response Type: <class 'langchain_core.messages.ai.AIMessage'>
#
# Content: LangChain is a framework that enables developers to build applications powered by large language models by chaining together prompts, models, and external tools in a modular, programmable workflow.
#
# Response Metadata:
# {'token_usage': {'completion_tokens': 69, 'prompt_tokens': 79, 'total_tokens': 148, 'completion_time': 0.14440167, 'completion_tokens_details': {'reasoning_tokens': 27}, 'prompt_time': 0.003217472, 'prompt_tokens_details': None, 'queue_time': 0.045231638, 'total_time': 0.147619142}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_a09bde29de', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}
#
# Tokens Used:
#   Prompt: 79
#   Completion: 69
#   Total: 148

# %% [markdown]
# ### 🔰 BEGINNER: Using Prompts
#
# Instead of plain strings, use **prompt templates** for better control:

# %%
from langchain_core.prompts import ChatPromptTemplate


# Create a prompt template
# {topic} is a variable we'll fill in later
prompt = ChatPromptTemplate.from_template(
    "Explain {topic} in simple terms suitable for beginners."
)

# View the prompt structure
print("Prompt Template:")
print(prompt.messages[0].prompt.template)
# Out:
# Prompt Template:
# Explain {topic} in simple terms suitable for beginners.

# %%
# Build a chain: Prompt → LLM
from langchain_core.output_parsers import StrOutputParser

# Components:
# 1. prompt: Formats the input
# 2. llm: Generates the response
# 3. StrOutputParser: Extracts just the text from the response

chain = prompt | llm | StrOutputParser()

# Use the chain with different topics
topics = ["machine learning", "embeddings", "vector databases"]

for topic in topics:
    print(f"\n{'='*60}")
    print(f"Topic: {topic.upper()}")
    print('='*60)
    
    # Invoke the chain
    explanation = chain.invoke({"topic": topic})
    print(explanation)
# Out:
# ============================================================
# Topic: MACHINE LEARNING
# ============================================================
# **Machine Learning (ML) in Plain English**
#
# Imagine you have a very smart robot that can learn from experience—just like a child learns to recognize a cat by seeing many pictures of cats. Machine learning is the way we teach computers to do that: **learn patterns from data** so they can make predictions or decisions without being told exactly how to do it every time.
#
# Below is a step‑by‑step, jargon‑free guide to what ML is, how it works, and why it matters.
#
# ---
#
# ## 1. The Core Idea
#
# | Human Learning | Machine Learning |
# |----------------|------------------|
# | **See** many examples (e.g., cats, dogs) → **Notice** patterns (whiskers, meow) → **Guess** “this is a cat” when you see a new picture. | **Feed** the computer lots of data (pictures, numbers, text) → **Algorithm** finds patterns → **Predict** the answer for new, unseen data. |
#
# In short: **ML = computers finding patterns in data so they can act on new data.**
#
# ---
#
# ## 2. Everyday Analogies
#
# | Analogy | What It Shows |
# |--------|---------------|
# | **Spam filter** in email | The program looks at many past emails labeled “spam” or “not spam”. It learns which words, senders, or formats usually mean spam, then automatically moves new spam to the junk folder. |
# | **Netflix recommendations** | Netflix watches what you and millions of other users have watched, learns what you like, and suggests new movies you’re likely to enjoy. |
# | **Self‑driving car** | The car’s sensors collect data about the road, other cars, and traffic signs. The ML model learns how to steer, brake, and accelerate safely. |
# | **Voice assistants (Siri, Alexa)** | They hear many spoken commands, learn how words sound, and turn your speech into actions. |
#
# ---
#
# ## 3. How a Simple ML Project Works (Step‑by‑Step)
#
# 1. **Collect Data**
#    *Example*: 1,000 pictures of handwritten digits (0‑9).
#    *Why*: The model needs examples to learn from.
#
# 2. **Label the Data** (optional for some methods)
#    *Example*: Each picture is tagged with the correct digit (the “label”).
#    *Why*: The model knows the right answer for each example.
#
# 3. **Choose a Model (Algorithm)**
#    *Think of it as a recipe*: Linear regression, decision tree, neural network, etc.
#    *For beginners*: A **decision tree** is easy to picture—it asks a series of yes/no questions until it reaches a decision.
#
# 4. **Train the Model**
#    *The computer runs the algorithm on the labeled data, adjusting internal “knobs” (parameters) to reduce mistakes.*
#    *Analogy*: Like a student solving practice problems and getting feedback.
#
# 5. **Validate / Test**
#    *Hold back some data the model hasn’t seen (the “test set”). See how well it predicts those answers.*
#    *If it does well, the model has learned useful patterns; if not, you may need more data or a different model.*
#
# 6. **Deploy**
#    *Put the trained model into a real‑world app (e.g., a mobile app that reads handwritten numbers).*
#
# 7. **Monitor & Update**
#    *Data changes over time, so you may need to retrain the model later.*
#
# ---
#
# ## 4. Types of Machine Learning (Very Brief)
#
# | Type | How It Learns | Simple Example |
# |------|---------------|----------------|
# | **Supervised Learning** | Learns from *labeled* data (input + correct answer). | Predict house prices from past sales data. |
# | **Unsupervised Learning** | Finds structure in *unlabeled* data (no explicit answer). | Group customers into segments based on buying habits. |
# | **Reinforcement Learning** | Learns by trial‑and‑error, receiving rewards/punishments. | A robot learns to navigate a maze by getting a “point” when it reaches the exit. |
# | **Semi‑Supervised / Self‑Supervised** | Mix of labeled + unlabeled data; the model creates its own labels. | Language models (like ChatGPT) learn from massive text without human tags. |
#
# ---
#
# ## 5. Why Machine Learning Is Powerful
#
# - **Automation**: Replaces repetitive, rule‑based tasks (e.g., sorting emails).
# - **Scalability**: Handles huge amounts of data far beyond human capacity.
# - **Adaptability**: Improves over time as more data arrives.
# - **Insight**: Reveals hidden patterns that humans might miss (e.g., early disease markers in medical data).
#
# ---
#
# ## 6. Common Misconceptions (and the truth)
#
# | Myth | Reality |
# |------|---------|
# | **ML = AI** | ML is a *subset* of AI. AI includes rule‑based systems, robotics, etc. |
# | **ML always needs massive data** | Some algorithms work well with small datasets; the key is *quality* and relevance. |
# | **ML models are always “black boxes”** | Some models (decision trees, linear regression) are fully interpretable. Others (deep neural nets) are more opaque, but techniques exist to explain them. |
# | **ML will replace all jobs** | It automates certain tasks, but it also creates new roles (data curators, ML engineers, ethicists). |
#
# ---
#
# ## 7. A Tiny Hands‑On Example (Python‑like Pseudocode)
#
# > *You don’t need to run this, it’s just to show the flow.*
#
# ```python
# # 1. Load data (e.g., a CSV file with house size and price)
# data = load_csv('houses.csv')
#
# # 2. Split into features (X) and label (y)
# X = data['size_sqft']          # input
# y = data['price_usd']          # what we want to predict
#
# # 3. Split into training and test sets
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#
# # 4. Choose a simple model: Linear Regression
# model = LinearRegression()
#
# # 5. Train (fit) the model
# model.fit(X_train, y_train)
#
# # 6. Predict on new data
# predictions = model.predict(X_test)
#
# # 7. Evaluate (how close are we?)
# error = mean_absolute_error(y_test, predictions)
# print(f'Average error: ${error:,.0f}')
# ```
#
# *What’s happening?*
# - The model learns a straight line that best fits “size → price”.
# - After training, you can give it a new house size and it will output an estimated price.
#
# ---
#
# ## 8. Getting Started (If You Want to Try)
#
# | Step | Resource |
# |------|----------|
# | **Learn the basics** | “Machine Learning for Humans” (free PDF), Coursera’s “AI For Everyone” by Andrew Ng. |
# | **Play with a visual tool** | Google’s **Teachable Machine** (drag‑and‑drop images/audio to train a model in the browser). |
# | **Write a tiny program** | Install **Python** + **scikit‑learn** (`pip install scikit-learn`). Follow the 7‑line example above. |
# | **Join a community** | Reddit r/MachineLearning, Stack Overflow, Kaggle (has beginner‑friendly datasets and notebooks). |
# | **Read about ethics** | “Weapons of Math Destruction” (book) – why responsible use matters. |
#
# ---
#
# ## 9. Quick Recap (Bullet Points)
#
# - **Machine Learning = computers learning from data** to make predictions or decisions.
# - **Data → Model → Prediction** is the basic pipeline.
# - **Supervised** (with labels) is the most common for beginners.
# - **Training** = the model adjusts itself to reduce errors on known data.
# - **Testing** checks if the model works on new, unseen data.
# - **Real‑world uses**: email spam filters, recommendation engines, voice assistants, medical diagnosis, self‑driving cars, etc.
# - **You can start now** with free online tools, a few lines of code, and lots of community help.
#
# ---
#
# ### Final Thought
#
# Think of machine learning as **teaching a computer to be a good “pattern‑spotter.”** Just as you learned to recognize faces, words, or smells by repeated exposure, a machine does the same—only it can do it at a scale and speed that opens up whole new possibilities. With a little curiosity and some practice, you can start building your own pattern‑spotters today! 🚀
#
# ============================================================
# Topic: EMBEDDINGS
# ============================================================
# ## What Is an “Embedding”?
#
# Think of an **embedding** as a way of turning something you can’t easily measure (a word, a picture, a product, a user, etc.) into a list of numbers that a computer can understand and work with.
#
# - **Numbers →** computers love numbers.
# - **List of numbers →** called a **vector** (e.g., `[0.23, -1.5, 3.0, …]`).
# - **Embedding →** that vector is a *compact, meaningful* representation of the original item.
#
# In short: **Embedding = “turn this thing into a short list of numbers that capture its meaning.”**
#
#
#
# ---
#
# ## Why Do We Need Embeddings?
#
# | Before embeddings | After embeddings |
# |-------------------|------------------|
# | “cat”, “dog”, “car” are just strings of characters. | Each word becomes a point in a multi‑dimensional space. |
# | A computer can’t tell that “cat” and “dog” are similar. | Distance between vectors tells the computer “cat” and “dog” are close, “car” is far away. |
# | Hard to feed raw text or images into a model. | Vectors can be fed directly into machine‑learning models (neural nets, classifiers, search engines, …). |
#
# So embeddings let us **measure similarity**, **perform arithmetic**, and **feed data into algorithms** in a way that respects the underlying meaning.
#
#
#
# ---
#
# ## A Simple Analogy: A Map of a City
#
# Imagine you have a city map:
#
# | City Feature | On the map (coordinates) |
# |--------------|--------------------------|
# | Library      | (2, 5)                   |
# | Coffee shop  | (3, 5)                   |
# | Hospital     | (8, 1)                   |
#
# - The **coordinates** are numbers that tell you where each place is.
# - Places that are **close together** on the map are also **close in real life** (you can walk between them quickly).
#
# An embedding works the same way, except:
#
# - The “city” is a **semantic space** (meaning of words, images, users, etc.).
# - The “coordinates” are usually **dozens or hundreds of numbers**, not just two.
# - “Close together” means “similar in meaning” rather than “physically near”.
#
# ---
#
# ## How Do We Create Word Embeddings? (A Very High‑Level View)
#
# 1. **Collect lots of text** (books, articles, web pages).
# 2. **Look at contexts**: which words appear near each other?
#    - “cat” often appears near “meow”, “purr”, “fur”.
#    - “dog” often appears near “bark”, “tail”, “walk”.
# 3. **Teach a tiny neural network** to predict a word from its neighbors (or vice‑versa).
# 4. **Read the hidden layer** of that network – those hidden‑layer values become the embedding vectors.
#
# Popular algorithms that follow this idea:
#
# | Algorithm | Typical dimension | What it captures |
# |-----------|-------------------|------------------|
# | **Word2Vec** (skip‑gram / CBOW) | 50‑300 | “king – man + woman ≈ queen” |
# | **GloVe** | 50‑300 | Global co‑occurrence statistics |
# | **FastText** | 300 | Sub‑word (character n‑gram) info, good for rare words |
# | **BERT / GPT** | 768‑4096 (depends on model size) | Context‑dependent embeddings (the same word can have different vectors in different sentences) |
#
# > **Key intuition:** Words that appear in similar contexts end up with **similar vectors**.
#
# ---
#
# ## Embeddings for Other Things
#
# | Thing | How we get an embedding | Example use |
# |-------|------------------------|-------------|
# | **Images** | Pass the picture through a convolutional neural network (CNN) and take the activations from a middle layer. | Find visually similar images, power “search by image”. |
# | **Users** | Use their activity (clicks, purchases, ratings) as input to a recommendation model. | Recommend movies, products, friends. |
# | **Products** | Combine text description, price, category, and purchase patterns. | Show “customers who bought this also bought …”. |
# | **Graphs (nodes/edges)** | Graph‑neural networks (e.g., Node2Vec, GraphSAGE). | Detect fraud, recommend connections on social networks. |
#
# The **same principle** applies: a complex object → a numeric vector that preserves the important relationships.
#
# ---
#
# ## What Does a Vector Look Like? (Very Small Example)
#
# Suppose we train a tiny Word2Vec model with 3‑dimensional vectors:
#
# | Word | Vector (x, y, z) |
# |------|-----------------|
# | cat  | (0.9, 0.1, -0.2) |
# | dog  | (0.85, 0.12, -0.15) |
# | car  | (-0.3, 0.8, 0.5) |
# | bike | (-0.25, 0.78, 0.45) |
#
# - **Similarity** is measured by the **dot product** or **cosine similarity**.
#   - `cosine(cat, dog) ≈ 0.99` → very similar.
#   - `cosine(cat, car) ≈ -0.2` → not similar.
#
# Even with just three numbers we can already tell which words belong together.
#
# ---
#
# ## Common Operations with Embeddings
#
# | Operation | What it does | Example |
# |-----------|--------------|---------|
# | **Distance / similarity** | Find items that are “close”. | Search for synonyms of “happy”. |
# | **Arithmetic** | Combine meanings. | `king - man + woman ≈ queen`. |
# | **Clustering** | Group similar items together. | Organize news articles by topic. |
# | **Classification** | Feed vectors into a simple model (logistic regression, SVM, small neural net). | Spam‑detect an email using its word‑embedding average. |
#
# ---
#
# ## Quick “Hands‑On” Thought Experiment
#
# 1. **Pick three words** you think are related, e.g., *apple, banana, car*.
# 2. **Imagine you have their vectors** (say 5‑dimensional).
# 3. **Compute cosine similarity** between each pair.
#    - You’ll likely see *apple* and *banana* have a higher similarity than either has with *car*.
# 4. **Interpret the result**: the model has learned that fruit words cluster together.
#
# You can try this yourself with Python libraries like `gensim` or `sentence‑transformers`—they’ll give you the numbers and the similarity scores instantly.
#
# ---
#
# ## Bottom‑Line Summary (Bullet Form)
#
# - **Embedding = numeric vector that captures meaning.**
# - **Why?** Numbers let computers compare, combine, and learn from items that are otherwise just text or pixels.
# - **How?** Train a model on lots of data; the model’s hidden layer becomes the embedding.
# - **What does it look like?** A list of 50‑300 (or more) floating‑point numbers.
# - **What can you do with it?** Find similar items, do arithmetic, feed it to downstream ML models, visualize clusters, etc.
# - **Beyond words:** Images, users, products, graph nodes—all can be embedded.
#
# ---
#
# ## A Tiny Code Sketch (Python)
#
# ```python
# # Install once: pip install sentence-transformers
# from sentence_transformers import SentenceTransformer, util
#
# model = SentenceTransformer('all-MiniLM-L6-v2')   # a small, fast model
# sentences = ["I love pizza", "I enjoy pasta", "The car is fast"]
# embeds = model.encode(sentences)                # shape: (3, 384)
#
# # Find which sentences are most similar
# similarity = util.cos_sim(embeds, embeds)       # 3x3 matrix
# print(similarity)
# ```
#
# Output (rounded) might look like:
#
# ```
# [[1.00 0.87 0.12]
#  [0.87 1.00 0.10]
#  [0.12 0.10 1.00]]
# ```
#
# Interpretation: *“I love pizza”* and *“I enjoy pasta”* are very similar (0.87), while both are unrelated to *“The car is fast”* (≈0.1).
#
# ---
#
# ## Takeaway
#
# Embeddings are **the lingua franca of modern AI**: they turn messy, high‑level concepts into tidy rows of numbers that machines can reason about. Once you grasp the idea of “meaning as coordinates”, you can start exploring countless applications—from chatbots that understand sentences to recommendation engines that know which products you’ll like. Happy vector‑hunting!
#
# ============================================================
# Topic: VECTOR DATABASES
# ============================================================
# ## What Is a “Vector Database”?
# *(A simple, beginner‑friendly explanation)*
#
# | Concept | Everyday analogy | What it really means |
# |---------|------------------|----------------------|
# | **Vector** | A list of numbers that describes something, like a recipe’s ingredients (flour = 2 cups, sugar = 1 cup, …) | A fixed‑length array of floating‑point numbers (e.g., `[0.12, -0.87, 0.33, …]`) that captures the meaning or features of an item (text, image, sound, etc.). |
# | **Embedding** | Turning a complex thing (a paragraph, a photo) into that recipe list so a computer can compare them | A function (usually a neural network) that maps raw data → a vector. Similar items get vectors that point in roughly the same direction. |
# | **Similarity Search** | Finding recipes that use the same ingredients, even if the exact amounts differ | Measuring how close two vectors are (e.g., cosine similarity, Euclidean distance) and returning the most similar ones. |
# | **Vector Database** | A pantry that stores all those recipe lists and can quickly fetch the “most similar” recipes when you ask for “something like this” | A specialized data store built to hold millions (or billions) of vectors and answer fast similarity queries. |
#
# ---
#
# ## 1. Why Do We Need Vectors at All?
#
# Traditional databases (SQL, NoSQL) are great at exact matches:
# - “Give me the row where `id = 42`.”
# - “Find all users whose age is 30.”
#
# But many modern AI tasks need **“near‑matches”** instead of exact matches:
#
# | Task | What we want | How a vector helps |
# |------|--------------|--------------------|
# | **Search** | “Find articles about *machine learning* that are similar to this paragraph.” | Convert each article to a vector; compare vectors to the query vector. |
# | **Recommendation** | “Show me movies like *Inception*.” | Movie embeddings capture genre, style, mood; similar vectors → similar movies. |
# | **Anomaly detection** | “Spot unusual sensor readings.” | Normal readings cluster together; outliers have vectors far from the cluster. |
# | **Semantic matching** | “Match a customer’s free‑text complaint to the right support category.” | Text → vector; categories also have vectors; nearest category wins. |
#
# In all these cases we need a **fast way to find the nearest vectors** among huge collections. That’s what a vector database does.
#
# ---
#
# ## 2. How Does a Vector Database Work? (High‑level)
#
# 1. **Store vectors** – each record has an ID and a fixed‑length vector (e.g., 768‑dimensional).
# 2. **Index the vectors** – build a data structure that lets us approximate “nearest neighbor” queries quickly. Common indexes:
#    - **IVF (Inverted File)** – groups vectors into coarse clusters, then searches only inside the most promising clusters.
#    - **HNSW (Hierarchical Navigable Small World graph)** – builds a graph where each node (vector) is linked to a few “nearby” nodes; search walks the graph toward the query.
#    - **PQ (Product Quantization)** – compresses vectors to save memory while still allowing distance estimates.
# 3. **Query** – you give the DB a *query vector* (often the embedding of a user’s search phrase or an image). The DB returns the top‑K IDs whose stored vectors are closest.
# 4. **Optional filtering** – you can combine vector similarity with traditional filters (e.g., “nearest movies **released after 2015**”).
#
# The key point: **the DB does the heavy math for you** and does it in milliseconds even for millions of vectors.
#
# ---
#
# ## 3. Simple Example (Python‑style Pseudocode)
#
# ```python
# # 1️⃣ Create embeddings (vectors) for some sentences
# sentences = [
#     "I love hiking in the mountains.",
#     "The movie was thrilling and full of action.",
#     "How to bake a chocolate cake?"
# ]
#
# # Suppose `embed(text)` returns a 768‑dim float list
# vectors = [embed(s) for s in sentences]
#
# # 2️⃣ Insert into a vector DB (e.g., using the popular library `faiss` or a cloud service)
# db = VectorDB(dim=768)          # tells the DB the vector size
# for i, vec in enumerate(vectors):
#     db.upsert(id=i, vector=vec) # store each vector with an ID
#
# # 3️⃣ Query: "I enjoy outdoor adventures"
# query_vec = embed("I enjoy outdoor adventures")
# top_ids = db.search(query_vec, k=2)   # ask for the 2 most similar items
#
# print(top_ids)   # → [0, 2]  (the first sentence about hiking is the best match)
# ```
#
# *What happened?*
# - The query sentence was turned into a vector.
# - The DB compared that vector to all stored vectors (using the index) and returned the IDs of the closest ones.
# - No exact keyword matching was needed; the similarity is **semantic** (meaning‑based).
#
# ---
#
# ## 4. When to Use a Vector Database vs. a Regular Database
#
# | Situation | Use a regular relational/NoSQL DB | Use a vector DB |
# |-----------|-----------------------------------|-----------------|
# | Look up a user by exact email | ✅ `SELECT * FROM users WHERE email='alice@example.com'` | ❌ Not needed |
# | Find products whose **price** is < $20 | ✅ `WHERE price < 20` | ❌ Not needed |
# | Search for “documents about **climate change**” (semantic) | ❌ Full‑text search can help but misses nuance | ✅ Store embeddings of docs, query with embedding of the phrase |
# | Recommend songs similar to a user’s listening history | ❌ Hard to express similarity with simple columns | ✅ Store song embeddings, query with user’s “taste vector” |
# | Detect fraudulent transactions that deviate from normal patterns | ❌ Rule‑based checks may miss subtle patterns | ✅ Train an embedding model, store transaction vectors, flag outliers |
#
# **Rule of thumb:**
# - If you need **exact matches** → regular DB.
# - If you need **“close enough”** based on meaning, style, or high‑dimensional features → vector DB.
#
# ---
#
# ## 5. Popular Vector Database Options (Beginner‑friendly)
#
# | Name | Hosted / Self‑hosted | Easy to start? | Typical use‑case |
# |------|----------------------|----------------|------------------|
# | **Pinecone** | Cloud (managed) | Very easy – just an API key | Production‑grade recommendation, semantic search |
# | **Weaviate** | Cloud + open‑source | UI + GraphQL/REST API | Knowledge graphs + vector search |
# | **Qdrant** | Self‑hosted (Docker) + Cloud | Simple HTTP API, open source | Fast HNSW search, good for dev & on‑prem |
# | **Milvus** | Self‑hosted (K8s/Docker) | More setup, but powerful | Large‑scale (billions) vectors, many index types |
# | **FAISS** (Facebook AI Similarity Search) | Library (Python/C++) | No server, just code | Prototyping, research, small‑to‑medium datasets |
# | **Elastic Search + k‑NN plugin** | Extends a familiar search engine | Good if you already use Elastic | Combine text search + vector search |
#
# All of these let you **store vectors, create an index, and run a `search(query_vector, k)` call**. The main differences are cost, scalability, and extra features (metadata filtering, hybrid search, security, etc.).
#
# ---
#
# ## 6. Key Terms You’ll Hear
#
# | Term | Simple meaning |
# |------|----------------|
# | **Embedding** | A vector that represents an item’s meaning. |
# | **Dimensionality** | How many numbers are in each vector (e.g., 128, 512, 1536). |
# | **Cosine similarity** | Measures the angle between two vectors; 1 = identical direction, 0 = orthogonal (unrelated). |
# | **Euclidean distance** | Straight‑line distance in the vector space. |
# | **ANN (Approximate Nearest Neighbor)** | Fast, “good‑enough” search; exact nearest neighbor would be too slow for large data. |
# | **Metadata** | Extra fields you store alongside the vector (e.g., title, timestamp, category). |
# | **Hybrid search** | Combining vector similarity with traditional filters (e.g., “nearest vectors **where** `category='news'`”). |
#
# ---
#
# ## 7. Quick “Hands‑On” Checklist for a Beginner
#
# 1. **Pick an embedding model** – e.g., OpenAI’s `text-embedding-ada-002`, Sentence‑Transformers, CLIP (for images).
# 2. **Generate vectors** for the items you want to search/recommend.
# 3. **Choose a vector DB** (Pinecone for zero‑setup, Qdrant for local Docker, FAISS for pure code).
# 4. **Load the vectors** into the DB (usually a bulk `upsert` operation).
# 5. **Query** by turning a user’s input into a vector and calling `search`.
# 6. **Use the returned IDs** to fetch the full records (title, URL, image, etc.) from your regular database or from the DB’s metadata store.
#
# ---
#
# ## 8. Visual Metaphor (If You Like Pictures)
#
# Imagine a **library** where every book is placed on a **shelf that represents its theme**.
# - Traditional DB: you have to know the exact **catalog number** to fetch a book.
# - Vector DB: you walk in, describe the story you’re looking for (“a detective who solves crimes with math”), and the librarian (the DB) points you to the nearest shelves where similar books sit, even if you never saw their exact titles.
#
# The “shelf coordinates” are the vectors; the librarian’s quick lookup is the ANN index.
#
# ---
#
# ## 9. Common Pitfalls for Beginners
#
# | Pitfall | Why it hurts | How to avoid |
# |---------|--------------|--------------|
# | **Using too low‑dimensional vectors** (e.g., 8‑dim) for complex data | Not enough capacity to capture nuance → poor search quality | Start with model‑provided dimensions (e.g., 384, 768, 1536). |
# | **Skipping metadata** | You can’t filter by date, category, etc. | Store useful fields alongside each vector; most DBs let you filter on them. |
# | **Expecting exact matches** | Vectors are fuzzy; “nearest” is never 100 % identical | Accept that results are similarity‑based; tune `k` and similarity thresholds. |
# | **Over‑loading the DB with frequent re‑embeddings** | Re‑computing embeddings for every tiny change wastes compute | Batch updates; only re‑embed when the underlying content changes significantly. |
# | **Ignoring distance metric** | Cosine vs. Euclidean can change ranking | Use the metric recommended by your embedding model (most text embeddings work best with cosine). |
#
# ---
#
# ## 10. TL;DR (One‑sentence summary)
#
# A **vector database** is a specialized store that keeps high‑dimensional numeric representations (embeddings) of items and can instantly find the most *similar* items, enabling AI‑powered search, recommendation, and pattern‑matching that go beyond exact keyword matches.
#
# ---
#
# ### Want to try it right now?
#
# 1. **Sign up for a free Pinecone account** (or run `docker run qdrant/qdrant`).
# 2. Use the OpenAI API to get a text embedding:
#
# ```bash
# pip install openai pinecone-client
# ```
#
# ```python
# import openai, pinecone
#
# openai.api_key = "YOUR_OPENAI_KEY"
# pinecone.init(api_key="YOUR_PINECONE_KEY", environment="us-west1-gcp")
#
# index = pinecone.Index("demo")
# vectors = [openai.Embedding.create(input=s, model="text-embedding-ada-002")["data"][0]["embedding"]
#            for s in ["I love pizza", "Space rockets are cool", "How to fix a leaky faucet?"]]
#
# index.upsert(vectors=[(str(i), v) for i, v in enumerate(vectors)])
#
# query = openai.Embedding.create(input="I enjoy Italian food", model="text-embedding-ada-002")["data"][0]["embedding"]
# result = index.query(vector=query, top_k=2)
# print(result.matches)   # shows the IDs of the most similar stored sentences
# ```
#
# That’s a **complete, minimal pipeline**: embed → store → query. Once you see it work, you can replace the toy sentences with your own documents, images, or product data.
#
# Happy vector hunting! 🚀

# %% [markdown]
# ### 🎓 INTERMEDIATE: Batch Processing
#
# Process multiple inputs efficiently using `.batch()`:

# %%
# Batch process multiple topics at once
topics_batch = [
    {"topic": "RAG"},
    {"topic": "LCEL"},
    {"topic": "LangChain agents"}
]

# Batch processing is more efficient than calling invoke() multiple times
results = chain.batch(topics_batch)

# Print results
for i, (input_dict, result) in enumerate(zip(topics_batch, results), 1):
    print(f"\n{i}. {input_dict['topic'].upper()}:")
    print(f"   {result[:100]}...")  # Print first 100 chars
# Out:
# 1. RAG:
#    **RAG = Retrieval‑Augmented Generation**
# *(a way to make AI answers smarter by letting the model l...
#
# 2. LCEL:
#    ## LCEL in a nutshell
# **LCEL = LangChain Expression Language**
#
# Think of LCEL as a *tiny, friend...
#
# 3. LANGCHAIN AGENTS:
#    ## LangChain Agents – A Beginner‑Friendly Overview
#
# ### 1. What’s the big idea?
# Think of a **Lan...

# %% [markdown]
# <a id="comparison"></a>
# ## 6. LangChain vs Traditional ML Pipelines 🆚
#
# ### 🔰 BEGINNER: Key Differences
#
# | Aspect | Traditional ML | LangChain |
# |--------|---------------|------------|
# | **Setup** | Complex, manual | Pre-built components |
# | **Integration** | Write custom code | Use existing integrations |
# | **Composability** | Difficult to chain | Easy with LCEL |
# | **Debugging** | Manual logging | Built-in callbacks |
# | **Prototyping** | Slow | Very fast |
# | **Code Reuse** | Limited | High |
#
# ### Example: Building a Q&A System
#
# #### Without LangChain (50+ lines):
# ```python
# import openai
# import PyPDF2
# import faiss
# import numpy as np
#
# # 1. Load PDF manually
# def load_pdf(file_path):
#     reader = PyPDF2.PdfReader(file_path)
#     text = ""
#     for page in reader.pages:
#         text += page.extract_text()
#     return text
#
# # 2. Split text manually
# def split_text(text, chunk_size=1000):
#     chunks = []
#     for i in range(0, len(text), chunk_size):
#         chunks.append(text[i:i+chunk_size])
#     return chunks
#
# # 3. Create embeddings manually
# def create_embeddings(chunks):
#     embeddings = []
#     for chunk in chunks:
#         response = openai.Embedding.create(
#             input=chunk,
#             model="text-embedding-ada-002"
#         )
#         embeddings.append(response['data'][0]['embedding'])
#     return np.array(embeddings)
#
# # 4. Create vector store manually
# def create_vector_store(embeddings):
#     dimension = embeddings.shape[1]
#     index = faiss.IndexFlatL2(dimension)
#     index.add(embeddings)
#     return index
#
# # 5. Search manually
# def search(query, index, chunks):
#     query_embedding = openai.Embedding.create(
#         input=query,
#         model="text-embedding-ada-002"
#     )['data'][0]['embedding']
#
#     distances, indices = index.search(
#         np.array([query_embedding]), k=3
#     )
#     return [chunks[i] for i in indices[0]]
#
# # 6. Generate answer manually
# def generate_answer(query, context):
#     prompt = f"Context: {context}\n\nQuestion: {query}\n\nAnswer:"
#     response = openai.ChatCompletion.create(
#         model="gpt-3.5-turbo",
#         messages=[{"role": "user", "content": prompt}]
#     )
#     return response['choices'][0]['message']['content']
#
# # Use it:
# text = load_pdf("document.pdf")
# chunks = split_text(text)
# embeddings = create_embeddings(chunks)
# index = create_vector_store(embeddings)
# relevant_chunks = search("What is RAG?", index, chunks)
# answer = generate_answer("What is RAG?", " ".join(relevant_chunks))
# ```
#
# #### With LangChain (10 lines!):
# ```python
# from langchain_community.document_loaders import PyPDFLoader
# from langchain_text_splitters import RecursiveCharacterTextSplitter
# from langchain_openai import OpenAIEmbeddings, ChatOpenAI
# from langchain_community.vectorstores import FAISS
# from langchain_core.prompts import ChatPromptTemplate
# from langchain_core.output_parsers import StrOutputParser
# from langchain_core.runnables import RunnablePassthrough
#
# # Load, split, embed, and store
# docs = PyPDFLoader("document.pdf").load()
# chunks = RecursiveCharacterTextSplitter(chunk_size=1000).split_documents(docs)
# vectorstore = FAISS.from_documents(chunks, OpenAIEmbeddings())
# retriever = vectorstore.as_retriever()
#
# # Build RAG chain
# prompt = ChatPromptTemplate.from_template(
#     "Context: {context}\n\nQuestion: {question}\n\nAnswer:"
# )
# chain = (
#     {"context": retriever, "question": RunnablePassthrough()}
#     | prompt | ChatOpenAI() | StrOutputParser()
# )
#
# # Use it:
# answer = chain.invoke("What is RAG?")
# ```
#
# **50+ lines → 10 lines!** 🎉

# %% [markdown]
# <a id="summary"></a>
# ## 7. Summary & Next Steps 📝
#
# ### 🎉 What You Learned
#
# ✅ **LangChain** is a framework that simplifies building LLM applications
#
# ✅ **Architecture** is modular: loaders, splitters, embeddings, vector stores, chains
#
# ✅ **Documents** contain `page_content` (text) and `metadata` (information about the text)
#
# ✅ **LCEL** uses the `|` operator to chain components together
#
# ✅ **Chains** connect multiple components to create complex workflows
#
# ✅ LangChain **dramatically reduces code** compared to manual implementations
#
# ### 🔰 For Beginners
# You now understand:
# - What LangChain is and why it's useful
# - How to set up your environment
# - Basic concepts: Documents and Chains
# - How to make your first LLM call
#
# ### 🎓 For Intermediate Learners
# You now understand:
# - LangChain's package structure (1.0+ reorganization)
# - LCEL internals and advantages
# - Metadata usage for filtering and citation
# - Batch processing for efficiency
#
# ### 📚 Next Notebooks
#
# 1. **Notebook 02**: Document Loaders (PDF, CSV, JSON, HTML)
# 2. **Notebook 03**: Text Splitting Strategies
# 3. **Notebook 04**: Embeddings and Vector Representations
# 4. **Notebook 05**: Vector Stores (FAISS, Chroma)
# 5. **Notebook 06**: Retrieval Strategies
# 6. **Notebook 07**: Complete RAG Pipeline
#
# ### 💡 Practice Exercises
#
# Before moving to the next notebook, try these:
#
# 1. **Easy**: Create 5 Documents about different topics with meaningful metadata
# 2. **Medium**: Build a chain that takes a topic and generates a haiku about it
# 3. **Advanced**: Create a chain that summarizes text in different styles (formal, casual, technical)
#
# ---
#
# ## 🎓 Additional Resources
#
# - [Official LangChain Documentation](https://python.langchain.com/docs/)
# - [LCEL Guide](https://python.langchain.com/docs/expression_language/)
# - [LangChain GitHub](https://github.com/langchain-ai/langchain)
#
# ---
#
# **Ready for more? Continue to Notebook 02: Document Loaders! 🚀**
